# %%
# %load_ext sql

# %%
# %sql sqlite:///chinook.db

# %%
# %sql SELECT track_id,name FROM track WHERE milliseconds > 5000000
# Out:
#  * sqlite:///chinook.db
# Done.
# [(2820, 'Occupation / Precipice'), (3224, 'Through a Looking Glass')]

# %%
# %sql SELECT invoice_id,total FROM invoice WHERE total BETWEEN 5 AND 15;
# Out:
#  * sqlite:///chinook.db
# Done.
# [(2, 9.9),
#  (4, 7.92),
#  (7, 10.89),
#  (8, 9.9),
#  (9, 8.91),
#  (11, 10.89),
#  (16, 8.91),
#  (17, 10.89),
#  (19, 6.93),
#  (20, 9.9),
#  (21, 8.91),
#  (23, 9.9),
#  (24, 11.879999999999999),
#  (25, 7.92),
#  (27, 7.92),
#  (29, 5.9399999999999995),
#  (30, 10.89),
#  (32, 12.87),
#  (36, 6.93),
#  (37, 9.9),
#  (38, 6.93),
#  (39, 7.92),
#  (40, 9.9),
#  (41, 7.92),
#  (42, 8.91),
#  (43, 6.93),
#  (44, 11.879999999999999),
#  (45, 7.92),
#  (46, 10.89),
#  (47, 5.9399999999999995),
#  (50, 6.93),
#  (51, 7.92),
#  (52, 11.879999999999999),
#  (55, 9.9),
#  (58, 5.9399999999999995),
#  (59, 10.89),
#  (60, 7.92),
#  (61, 11.879999999999999),
#  (63, 5.9399999999999995),
#  (64, 12.87),
#  (66, 6.93),
#  (67, 10.89),
#  (68, 10.89),
#  (69, 13.86),
#  (73, 14.85),
#  (76, 12.87),
#  (77, 5.9399999999999995),
#  (78, 8.91),
#  (79, 13.86),
#  (81, 5.9399999999999995),
#  (82, 6.93),
#  (84, 11.879999999999999),
#  (87, 7.92),
# ...

# %%
# %sql SELECT customer_id, first_name, last_name, company FROM customer WHERE state IN ('RJ', 'DF', 'AB', 'BC', 'CA', 'WA', 'NY');
# Out:
#  * sqlite:///chinook.db
# Done.
# [(12, 'Roberto', 'Almeida', 'Riotur'),
#  (13, 'Fernanda', 'Ramos', None),
#  (14, 'Mark', 'Philips', 'Telus'),
#  (15, 'Jennifer', 'Peterson', 'Rogers Canada'),
#  (16, 'Frank', 'Harris', 'Google Inc.'),
#  (17, 'Jack', 'Smith', 'Microsoft Corporation'),
#  (18, 'Michelle', 'Brooks', None),
#  (19, 'Tim', 'Goyer', 'Apple Inc.'),
#  (20, 'Dan', 'Miller', None)]

# %%
# %sql SELECT invoice_id,total FROM invoice WHERE (customer_id IN (56,58)) AND (total BETWEEN 5 AND 15);
# Out:
#  * sqlite:///chinook.db
# Done.
# [(218, 8.91),
#  (304, 6.93),
#  (380, 9.9),
#  (381, 12.87),
#  (82, 6.93),
#  (100, 5.9399999999999995),
#  (140, 7.92),
#  (146, 12.87),
#  (246, 8.91),
#  (285, 9.9),
#  (294, 10.89)]

# %%
# %sql SELECT * FROM invoice WHERE invoice_id=315;
# Out:
#  * sqlite:///chinook.db
# Done.
# [(315, 10, '2019-01-30 00:00:00', 'Rua Dr. Falcão Filho, 155', 'São Paulo', 'SP', 'Brazil', '01007-010', 4.95)]

# %%
# %sql SELECT track_id,name FROM track WHERE name LIKE 'All%';
# Out:
#  * sqlite:///chinook.db
# Done.
# [(38, 'All I Really Want'),
#  (134, 'All For You'),
#  (385, 'All Star'),
#  (1009, 'All My Life'),
#  (1608, 'All My Love'),
#  (1892, 'All Within My Hands'),
#  (2192, 'All or None'),
#  (2274, 'All Dead, All Dead'),
#  (2888, 'All the Best Cowboys Have Daddy Issues'),
#  (2969, 'All Because Of You'),
#  (2991, 'All Along The Watchtower'),
#  (3003, 'All I Want Is You'),
#  (3017, 'All I Want Is You'),
#  (3316, 'All My Love'),
#  (3374, 'All Night Thing')]

# %%
# %sql SELECT COUNT(track_id) FROM track WHERE name LIKE 'All%';
# Out:
#  * sqlite:///chinook.db
# Done.
# [(15,)]

# %%
# %sql SELECT email FROM customer WHERE email LIKE 'J%gmail.com';
# Out:
#  * sqlite:///chinook.db
# Done.
# [('jubarnett@gmail.com',)]

# %%
# %sql SELECT * FROM invoice WHERE billing_city IN ('Brasilia', 'Edmonton', 'Vancouver') ORDER BY invoice_id DESC;
# Out:
#  * sqlite:///chinook.db
# Done.
# [(609, 14, '2020-12-20 00:00:00', '8210 111 ST NW', 'Edmonton', 'AB', 'Canada', 'T6G 2C7', 2.9699999999999998),
#  (606, 15, '2020-12-18 00:00:00', '700 W Pender Street', 'Vancouver', 'BC', 'Canada', 'V6C 1G8', 11.879999999999999),
#  (575, 15, '2020-10-19 00:00:00', '700 W Pender Street', 'Vancouver', 'BC', 'Canada', 'V6C 1G8', 3.96),
#  (567, 15, '2020-09-27 00:00:00', '700 W Pender Street', 'Vancouver', 'BC', 'Canada', 'V6C 1G8', 7.92),
#  (564, 15, '2020-09-20 00:00:00', '700 W Pender Street', 'Vancouver', 'BC', 'Canada', 'V6C 1G8', 5.9399999999999995),
#  (530, 14, '2020-06-22 00:00:00', '8210 111 ST NW', 'Edmonton', 'AB', 'Canada', 'T6G 2C7', 0.99),
#  (483, 15, '2020-02-29 00:00:00', '700 W Pender Street', 'Vancouver', 'BC', 'Canada', 'V6C 1G8', 4.95),
#  (469, 14, '2020-01-28 00:00:00', '8210 111 ST NW', 'Edmonton', 'AB', 'Canada', 'T6G 2C7', 0.99),
# ...

# %%
# %sql SELECT customer_id, COUNT(*) FROM invoice GROUP BY customer_id ORDER BY COUNT(*) DESC;
# Out:
#  * sqlite:///chinook.db
# Done.
# [(5, 18),
#  (35, 16),
#  (13, 15),
#  (1, 13),
#  (30, 13),
#  (34, 13),
#  (46, 13),
#  (57, 13),
#  (58, 13),
#  (6, 12),
#  (10, 12),
#  (17, 12),
#  (20, 12),
#  (22, 12),
#  (26, 12),
#  (33, 12),
#  (43, 12),
#  (2, 11),
#  (12, 11),
#  (21, 11),
#  (31, 11),
#  (36, 11),
#  (42, 11),
#  (44, 11),
#  (50, 11),
#  (53, 11),
#  (9, 10),
#  (11, 10),
#  (14, 10),
#  (23, 10),
#  (25, 10),
#  (28, 10),
#  (37, 10),
#  (45, 10),
#  (48, 10),
#  (49, 10),
#  (51, 10),
#  (55, 10),
#  (3, 9),
#  (4, 9),
#  (7, 9),
#  (15, 9),
#  (19, 9),
#  (27, 9),
#  (38, 9),
#  (39, 9),
#  (40, 9),
#  (41, 9),
#  (47, 9),
#  (54, 9),
#  (16, 8),
#  (18, 8),
#  (24, 8),
#  (32, 8),
#  (52, 8),
#  (59, 8),
#  (8, 7),
#  (56, 5),
#  (29, 4)]

# %%
# %sql SELECT COUNT(*) FROM (SELECT album_id, COUNT(*) FROM track GROUP BY album_id HAVING COUNT(*) >=12 );
# Out:
#  * sqlite:///chinook.db
# Done.
# [(158,)]
